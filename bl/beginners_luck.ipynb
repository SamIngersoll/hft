# %%
import time
import toml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from order_side import OrderSide
from ema_strategy import EMA_strategy

from binance.client import Client
from binance import ThreadedWebsocketManager

plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams["figure.dpi"] = 200
plt.rcParams.update({'font.size': 18})

# %%
cfg = toml.load("../api/configuration.toml")
pkey = cfg["auth"]["pkey"]
skey = cfg["auth"]["skey"]

client = Client(pkey, skey)

# %%
client.get_exchange_info()
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1622841429647,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 1200},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '922327.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1565.83636597',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'LTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '10720.64375000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BNBBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '11539.59463194',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'NEOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'NEO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7540.81639583',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'QTUMETH',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3986.98279166',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'EOSETH',
#    'status': 'TRADING',
#    'baseAsset': 'EOS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '37508.72782638',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'SNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'SNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '326759.33472222',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7582.06625000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BCCBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BCC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'GASBTC',
#    'status': 'TRADING',
#    'baseAsset': 'GAS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '23441.68565277',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BNBETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00001000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00001000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '2988.36990763',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BTCUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00000100',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00000100'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '142.88520602',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'ETHUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1847.62411824',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'HSRBTC',
#    'status': 'BREAK',
#    'baseAsset': 'HSR',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'OAXETH',
#    'status': 'BREAK',
#    'baseAsset': 'OAX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '579591.88919668',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'DNTETH',
#    'status': 'BREAK',
#    'baseAsset': 'DNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4194220.05124836',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'MCOETH',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6660.95529820',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'ICNETH',
#    'status': 'BREAK',
#    'baseAsset': 'ICN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'MCOBTC',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '27097.31944518',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '102603.88160416',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WTCETH',
#    'status': 'BREAK',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '28248.67398611',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'LRCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '370840.79166666',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'LRCETH',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '189318.78125000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'QTUMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '17726.38080555',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YOYOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'YOYO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '9057425.98194444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'OMGBTC',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '40742.34588888',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'OMGETH',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '11438.05260416',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'ZRXBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '208970.78680555',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'ZRXETH',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '49019.98611111',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'STRATBTC',
#    'status': 'BREAK',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '222217.01315789',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'STRATETH',
#    'status': 'BREAK',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '75043.65373961',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SNGLSBTC',
#    'status': 'TRADING',
#    'baseAsset': 'SNGLS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '21532735.64930555',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SNGLSETH',
#    'status': 'BREAK',
#    'baseAsset': 'SNGLS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6821000.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BQXBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BQX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '103437.22569444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BQXETH',
#    'status': 'TRADING',
#    'baseAsset': 'BQX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '23670.53125000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'KNCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'KNC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
# ...
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4206.37974166',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SXPAUD',
#    'status': 'TRADING',
#    'baseAsset': 'SXP',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'AUD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '23029.03450277',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BZRXBNB',
#    'status': 'BREAK',
#    'baseAsset': 'BZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00001000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00001000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '32864.14458333',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BZRXBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '229501.50000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BZRXBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'BZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '157485.89920833',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BZRXUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '599993.21955555',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'WBTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WBTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00001000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00001000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '192.01414945',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WBTCETH',
#    'status': 'TRADING',
#    'baseAsset': 'WBTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3.79933128',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SUSHIBNB',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00001000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00001000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '10549.84540972',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SUSHIBTC',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '50904.69006250',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'SUSHIBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '31403.16963888',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SUSHIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '83908.40922500',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   ...]}

# %%
class Trader:
    def __init__(self, async_optimization=False):
        self.base_arr = []
        self.quote_arr = []
        self.price_history = []
        self.base = 1
        self.quote = 0
        self.tr = EMA_strategy()
        self.optimization_period = 50
        self.optimize_async_result = None
        self.num_buys = 0
        self.num_sells = 0
        self.async_optimization = async_optimization
    
    def trade(self, price):
        self.price_history.append(price)
        if len(self.price_history) < self.optimization_period:
            return OrderSide.NO_OP
        elif len(self.price_history) == self.optimization_period:
            if self.async_optimization:
                self.optimize_async_result = self.tr.optimize_multiprocess_async(self.price_history[:])
            else:
                self.tr.optimize_multiprocess(self.price_history[:])
            return OrderSide.NO_OP
        elif self.async_optimization:
            if not self.optimize_async_result.ready():
                return OrderSide.NO_OP

        traded = False
        self.quote *= 1 + (self.price_history[-1] - self.price_history[-2]) / self.price_history[-2]

        action = self.tr.action(self.price_history[-1])
        if action == OrderSide.BUY:  # buy
            if self.base > 0: 
                self.quote += .999 * self.base
                self.base = 0
                self.num_buys += 1
                traded = True
        elif action == OrderSide.SELL:  # sell
            if self.quote > 0:
                self.base += 0.999 * self.quote
                self.quote = 0
                self.num_sells += 1
                traded = True

        self.base_arr.append(self.base)
        self.quote_arr.append(self.quote)

        if len(self.price_history) % self.optimization_period == 0:
            if self.async_optimization:
                self.tr.optimize_multiprocess_async(self.price_history[-self.optimization_period:-1])
            else:
                self.tr.optimize_multiprocess(self.price_history[-self.optimization_period:-1])
            print(f"base: {self.base}\tquote: {self.quote}\tNUM BUYS: {self.num_buys}\tNUM SELLS: {self.num_sells}")

        if traded:
            return action
        return OrderSide.NO_OP

# %%
t = Trader(async_optimization=True)

def cb(msg):
    t.trade(float(msg["c"]))

bm = ThreadedWebsocketManager(api_key=pkey, api_secret=skey)
bm.start_symbol_ticker_socket('MATICBUSD', cb)
bm.start()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ae08ed5bcd6f> in <module>
#       6
#       7 bm = ThreadedWebsocketManager(api_key=pkey, api_secret=skey)
# ----> 8 bm.start_symbol_ticker_socket('MATICBUSD', cb)
#       9 bm.start()
#
# /usr/local/lib/python3.9/site-packages/binance/streams.py in start_symbol_ticker_socket(self, callback, symbol)
#    1106
#    1107     def start_symbol_ticker_socket(self, callback: Callable, symbol: str) -> str:
# -> 1108         return self._start_async_socket(
#    1109             callback=callback,
#    1110             socket_name='symbol_ticker_socket',
#
# /usr/local/lib/python3.9/site-packages/binance/streams.py in _start_async_socket(self, callback, socket_name, params, path)
#    1036     ) -> str:
#    1037         while not self._bsm:
# -> 1038             time.sleep(0.1)
#    1039         socket = getattr(self._bsm, socket_name)(**params)
#    1040         path = path or socket._path  # noqa
#
# KeyboardInterrupt:

# %%
t = Trader()

history = pd.read_csv('../historical_data/binance_DOGEBTC_1m.csv') # dogecoin data
brices = history['open'].tolist()

bases = []
quotes = []

for p in brices:
    t.trade(p)
# Out:
# SET PARAMS: 0.0 9 0.0 0
# SET PARAMS: 0.2 5 0.2 0
# base: 1	quote: 0.0	NUM BUYS: 0	NUM SELLS: 0
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 0.9990000000000001	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 0.9696176470588237	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9696176470588237	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 0.9402352941176483	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9402352941176483	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9696176470588248	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 0.9696176470588248	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.6 1 0.6 2
# base: 0	quote: 0.999000000000002	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 0.9990000000000024	NUM BUYS: 1	NUM SELLS: 0
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9970029990000026	NUM BUYS: 2	NUM SELLS: 1
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 1.0574274231818208	NUM BUYS: 2	NUM SELLS: 1
# SET PARAMS: 0.2 5 0.2 0
# base: 1.056369995758639	quote: 0.0	NUM BUYS: 2	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 1.056369995758639	quote: 0.0	NUM BUYS: 2	NUM SELLS: 2
# SET PARAMS: 0.2 5 0.2 0
# base: 1.056369995758639	quote: 0.0	NUM BUYS: 2	NUM SELLS: 2
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 1.0553136257628803	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0872928265435753	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.055313625762882	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 1.055313625762882	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 5 0.2 0
# base: 0	quote: 1.055313625762882	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.055313625762882	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0233344249821885	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0233344249821885	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0233344249821885	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.055313625762882	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 1.0233344249821885	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 1.0233344249821885	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 1.0233344249821885	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 1.0233344249821883	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0233344249821883	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 1.0233344249821883	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0233344249821883	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0233344249821883	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9913552242014949	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9913552242014949	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9913552242014949	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9913552242014949	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9593760234208014	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9913552242014949	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.8 7 0.8 8
# base: 0	quote: 1.0233344249821883	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 0.9913552242014949	NUM BUYS: 3	NUM SELLS: 2
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0212887794666488	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0212887794666488	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.8 7 0.8 8
# base: 0	quote: 1.0542335788042825	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0212887794666488	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0542335788042825	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0542335788042825	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0212887794666488	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.2 9 0.2 0
# base: 0	quote: 1.0212887794666488	NUM BUYS: 4	NUM SELLS: 3
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0860657196183254	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0860657196183254	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0521261658802528	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.01818661214218	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9842470584041074	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.6 8 0.6 2
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9503075046660349	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279622	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.8824283971898895	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.8824283971898895	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.8824283971898895	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.950307504666035	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.2 3 0.2 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.2 3 0.2 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.8824283971898895	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.2 3 0.2 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.8824283971898895	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.2 3 0.2 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.2 3 0.2 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 0.9163679509279623	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.950307504666035	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.950307504666035	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.950307504666035	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 0.950307504666035	NUM BUYS: 5	NUM SELLS: 4
# SET PARAMS: 0.6 8 0.6 2
# base: 0.9493571971613689	quote: 0.0	NUM BUYS: 5	NUM SELLS: 5
# SET PARAMS: 0.1 9 0.1 0
# base: 0.9493571971613689	quote: 0.0	NUM BUYS: 5	NUM SELLS: 5
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0132976172354244	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.6 8 0.6 2
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.2 1 0.2 0
# base: 0	quote: 1.0508271586145141	NUM BUYS: 8	NUM SELLS: 7
# SET PARAMS: 0.1 9 0.1 0
# base: 1.0872683432936103	quote: 0.0	NUM BUYS: 8	NUM SELLS: 8
# SET PARAMS: 0.1 9 0.1 0
# base: 1.0872683432936103	quote: 0.0	NUM BUYS: 8	NUM SELLS: 8
# SET PARAMS: 0.0 9 0.0 0
# base: 1.0872683432936103	quote: 0.0	NUM BUYS: 8	NUM SELLS: 8
# SET PARAMS: 0.0 9 0.0 0
# base: 1.0872683432936103	quote: 0.0	NUM BUYS: 8	NUM SELLS: 8
# SET PARAMS: 0.1 9 0.1 0
# base: 1.0872683432936103	quote: 0.0	NUM BUYS: 8	NUM SELLS: 8
# SET PARAMS: 0.1 9 0.1 0
# base: 1.0872683432936103	quote: 0.0	NUM BUYS: 8	NUM SELLS: 8
# SET PARAMS: 0.0 9 0.0 0
# base: 1.1238482829423435	quote: 0.0	NUM BUYS: 9	NUM SELLS: 9
# SET PARAMS: 0.1 9 0.1 0
# base: 1.1238482829423435	quote: 0.0	NUM BUYS: 9	NUM SELLS: 9
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.2841802020321933	NUM BUYS: 13	NUM SELLS: 12
# SET PARAMS: 0.2 1 0.2 0
# base: 1.282896021830161	quote: 0.0	NUM BUYS: 13	NUM SELLS: 13
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.5122084541192475	NUM BUYS: 19	NUM SELLS: 18
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.5662158989092205	NUM BUYS: 19	NUM SELLS: 18
# SET PARAMS: 0.2 1 0.2 0
# base: 1.5646496830103114	quote: 0.0	NUM BUYS: 19	NUM SELLS: 19
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.8480186224783626	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.8480186224783626	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.8480186224783626	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.6 8 0.6 2
# base: 0	quote: 1.8480186224783626	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.7205690623074412	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.784293842392902	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 1.8480186224783626	NUM BUYS: 24	NUM SELLS: 23
# SET PARAMS: 0.0 9 0.0 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.0 9 0.0 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.1 9 0.1 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.2 1 0.2 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.1 9 0.1 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.2 1 0.2 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.2 1 0.2 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.0 9 0.0 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.2 1 0.2 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.2 1 0.2 0
# base: 1.8461706038558843	quote: 0.0	NUM BUYS: 24	NUM SELLS: 24
# SET PARAMS: 0.1 9 0.1 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.2 1 0.2 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.1 9 0.1 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.1 9 0.1 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.1 9 0.1 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.1 9 0.1 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.0 9 0.0 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.2 1 0.2 0
# base: 1.9082829698480182	quote: 0.0	NUM BUYS: 25	NUM SELLS: 25
# SET PARAMS: 0.2 1 0.2 0
# base: 1.972485037626695	quote: 0.0	NUM BUYS: 26	NUM SELLS: 26
# SET PARAMS: 0.0 9 0.0 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.1 9 0.1 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.2 1 0.2 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.0 9 0.0 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.1 9 0.1 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.1 9 0.1 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.0 9 0.0 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.1 9 0.1 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.1 9 0.1 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.2 1 0.2 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.2 1 0.2 0
# base: 2.107441866713256	quote: 0.0	NUM BUYS: 28	NUM SELLS: 28
# SET PARAMS: 0.1 9 0.1 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.0 9 0.0 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.1 9 0.1 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.2 1 0.2 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.0 9 0.0 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.0 9 0.0 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.0 9 0.0 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.2 1 0.2 0
# base: 2.178344415079614	quote: 0.0	NUM BUYS: 29	NUM SELLS: 29
# SET PARAMS: 0.2 1 0.2 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.0 9 0.0 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.2 1 0.2 0
# base: 2.251632401186508	quote: 0.0	NUM BUYS: 30	NUM SELLS: 30
# SET PARAMS: 0.1 9 0.1 0
# base: 2.4866251314324037	quote: 0.0	NUM BUYS: 33	NUM SELLS: 33
# SET PARAMS: 0.2 1 0.2 0
# base: 2.4866251314324037	quote: 0.0	NUM BUYS: 33	NUM SELLS: 33
# SET PARAMS: 0.0 9 0.0 0
# base: 2.4866251314324037	quote: 0.0	NUM BUYS: 33	NUM SELLS: 33
# SET PARAMS: 0.0 9 0.0 0
# base: 2.4866251314324037	quote: 0.0	NUM BUYS: 33	NUM SELLS: 33
# SET PARAMS: 0.2 1 0.2 0
# base: 2.4866251314324037	quote: 0.0	NUM BUYS: 33	NUM SELLS: 33
# SET PARAMS: 0.0 9 0.0 0
# base: 2.5702848809301937	quote: 0.0	NUM BUYS: 34	NUM SELLS: 34
# SET PARAMS: 0.2 1 0.2 0
# base: 2.5702848809301937	quote: 0.0	NUM BUYS: 34	NUM SELLS: 34
# SET PARAMS: 0.1 9 0.1 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.1 9 0.1 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.0 9 0.0 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.0 9 0.0 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.0 9 0.0 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.0 9 0.0 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.2 1 0.2 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.1 9 0.1 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.0 9 0.0 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.0 9 0.0 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.1 9 0.1 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.2 1 0.2 0
# base: 2.6567592700765426	quote: 0.0	NUM BUYS: 35	NUM SELLS: 35
# SET PARAMS: 0.1 9 0.1 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.0 9 0.0 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.0 9 0.0 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.1 9 0.1 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.0 9 0.0 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.1 9 0.1 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.1 9 0.1 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.2 1 0.2 0
# base: 2.7461429943062186	quote: 0.0	NUM BUYS: 36	NUM SELLS: 36
# SET PARAMS: 0.2 1 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 1 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 4 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.1 9 0.1 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 1 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 1 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.2 1 0.2 0
# base: 2.9340332665567814	quote: 0.0	NUM BUYS: 38	NUM SELLS: 38
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.2 1 0.2 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.1 9 0.1 0
# base: 3.1347789343492325	quote: 0.0	NUM BUYS: 40	NUM SELLS: 40
# SET PARAMS: 0.0 9 0.0 0
# base: 3.349259559954459	quote: 0.0	NUM BUYS: 42	NUM SELLS: 42
# SET PARAMS: 0.1 9 0.1 0
# base: 3.349259559954459	quote: 0.0	NUM BUYS: 42	NUM SELLS: 42
# SET PARAMS: 0.2 1 0.2 0
# base: 3.461941689740328	quote: 0.0	NUM BUYS: 43	NUM SELLS: 43
# SET PARAMS: 0.0 9 0.0 0
# base: 3.578414885027627	quote: 0.0	NUM BUYS: 44	NUM SELLS: 44
# SET PARAMS: 0.0 9 0.0 0
# base: 3.578414885027627	quote: 0.0	NUM BUYS: 44	NUM SELLS: 44
# SET PARAMS: 0.1 9 0.1 0
# base: 3.578414885027627	quote: 0.0	NUM BUYS: 44	NUM SELLS: 44
# SET PARAMS: 0.2 1 0.2 0
# base: 3.578414885027627	quote: 0.0	NUM BUYS: 44	NUM SELLS: 44
# SET PARAMS: 0.1 9 0.1 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.0 9 0.0 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.2 1 0.2 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.0 9 0.0 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.1 9 0.1 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.0 9 0.0 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.0 9 0.0 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.1 9 0.1 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.2 1 0.2 0
# base: 3.6988066920179015	quote: 0.0	NUM BUYS: 45	NUM SELLS: 45
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 3.947926048112225	NUM BUYS: 48	NUM SELLS: 47
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 4.088923406973375	NUM BUYS: 48	NUM SELLS: 47
# SET PARAMS: 0.0 9 0.0 0
# base: 4.084834483566402	quote: 0.0	NUM BUYS: 48	NUM SELLS: 48
# SET PARAMS: 0.0 9 0.0 0
# base: 4.084834483566402	quote: 0.0	NUM BUYS: 48	NUM SELLS: 48
# SET PARAMS: 0.1 9 0.1 0
# base: 4.084834483566402	quote: 0.0	NUM BUYS: 48	NUM SELLS: 48
# SET PARAMS: 0.0 9 0.0 0
# base: 4.084834483566402	quote: 0.0	NUM BUYS: 48	NUM SELLS: 48
# SET PARAMS: 0.2 1 0.2 0
# base: 4.084834483566402	quote: 0.0	NUM BUYS: 48	NUM SELLS: 48
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 4.080749649082835	NUM BUYS: 49	NUM SELLS: 48
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 4.080749649082839	NUM BUYS: 49	NUM SELLS: 48
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 4.2264907079786544	NUM BUYS: 49	NUM SELLS: 48
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 4.2264907079786544	NUM BUYS: 49	NUM SELLS: 48
# SET PARAMS: 0.0 9 0.0 0
# base: 4.222264217270676	quote: 0.0	NUM BUYS: 49	NUM SELLS: 49
# SET PARAMS: 0.2 1 0.2 0
# base: 4.222264217270676	quote: 0.0	NUM BUYS: 49	NUM SELLS: 49
# SET PARAMS: 0.2 1 0.2 0
# base: 4.222264217270676	quote: 0.0	NUM BUYS: 49	NUM SELLS: 49
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.1 9 0.1 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.1 9 0.1 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.1 9 0.1 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.2 1 0.2 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.1 9 0.1 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.2 1 0.2 0
# base: 4.364317622211078	quote: 0.0	NUM BUYS: 50	NUM SELLS: 50
# SET PARAMS: 0.0 9 0.0 0
# base: 4.6629229125857465	quote: 0	NUM BUYS: 52	NUM SELLS: 52
# SET PARAMS: 0.2 1 0.2 0
# base: 4.6629229125857465	quote: 0.0	NUM BUYS: 52	NUM SELLS: 52
# SET PARAMS: 0.2 1 0.2 0
# base: 4.819801791457897	quote: 0.0	NUM BUYS: 53	NUM SELLS: 53
# SET PARAMS: 0.0 9 0.0 0
# base: 4.981958686522371	quote: 0.0	NUM BUYS: 54	NUM SELLS: 54
# SET PARAMS: 0.2 1 0.2 0
# base: 4.981958686522371	quote: 0.0	NUM BUYS: 54	NUM SELLS: 54
# SET PARAMS: 0.0 9 0.0 0
# base: 4.981958686522371	quote: 0.0	NUM BUYS: 54	NUM SELLS: 54
# SET PARAMS: 0.2 1 0.2 0
# base: 4.981958686522371	quote: 0.0	NUM BUYS: 54	NUM SELLS: 54
# SET PARAMS: 0.0 9 0.0 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.1 9 0.1 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.0 9 0.0 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.1 9 0.1 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.2 1 0.2 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.2 1 0.2 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.2 1 0.2 0
# base: 5.322822791520747	quote: 0.0	NUM BUYS: 56	NUM SELLS: 56
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.1 9 0.1 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 4 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.0 9 0.0 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# SET PARAMS: 0.2 1 0.2 0
# base: 5.501903271216229	quote: 0.0	NUM BUYS: 57	NUM SELLS: 57
# ...
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 375.2481900312464	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 349.36900451185016	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.6 8 0.6 2
# base: 0	quote: 375.2481900312464	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 362.3085972715483	NUM BUYS: 189	NUM SELLS: 188
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.2 1 0.2 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 361.9462886742768	quote: 0.0	NUM BUYS: 189	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.97635506655064	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 361.58434238560227	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.97635506655047	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 388.36836774749867	NUM BUYS: 190	NUM SELLS: 189
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 374.6013787114839	quote: 0.0	NUM BUYS: 190	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 374.22677733277243	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 388.08702834509734	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.22677733277243	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.22677733277243	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 388.08702834509734	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.22677733277243	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 388.08702834509734	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.0 9 0.0 0
# base: 0	quote: 374.22677733277243	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.1 9 0.1 0
# base: 0	quote: 401.9472793574222	NUM BUYS: 191	NUM SELLS: 190
# SET PARAMS: 0.2 1 0.2 0
# base: 401.54533207806475	quote: 0.0	NUM BUYS: 191	NUM SELLS: 191
# SET PARAMS: 0.0 9 0.0 0
# base: 401.54533207806475	quote: 0.0	NUM BUYS: 191	NUM SELLS: 191
# SET PARAMS: 0.2 1 0.2 0
# base: 401.54533207806475	quote: 0.0	NUM BUYS: 191	NUM SELLS: 191
# SET PARAMS: 0.2 1 0.2 0
# base: 401.54533207806475	quote: 0.0	NUM BUYS: 191	NUM SELLS: 191

# %%
client.get_ticker("MATICBUSD")
