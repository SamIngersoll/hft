# %%
import pandas as pd

# %%
df = pd.read_pickle("ws_data1620417661.19819.pkl")

# %%
df
# Out:
#                e              E         s            p        P           w  \
# 0     24hrTicker  1620351016230  DOGEUSDT  -0.07602000  -11.985  0.59524009
# 1     24hrTicker  1620351017231  DOGEUSDT  -0.07633000  -12.036  0.59523956
# 2     24hrTicker  1620351018234  DOGEUSDT  -0.07678000  -12.101  0.59523861
# 3     24hrTicker  1620351019232  DOGEUSDT  -0.07717000  -12.162  0.59523839
# 4     24hrTicker  1620351020234  DOGEUSDT  -0.07737000  -12.189  0.59523811
# ...          ...            ...       ...          ...      ...         ...
# 2300  24hrTicker  1620353316539  DOGEUSDT  -0.12271000  -19.010  0.59218751
# 2301  24hrTicker  1620353317540  DOGEUSDT  -0.12245000  -18.972  0.59218346
# 2302  24hrTicker  1620353318540  DOGEUSDT  -0.12289000  -19.038  0.59218058
# 2303  24hrTicker  1620353319541  DOGEUSDT  -0.12201000  -18.902  0.59217809
# 2304  24hrTicker  1620353320540  DOGEUSDT  -0.12207000  -18.909  0.59217685
#
# ...

# %%
(max(df["E"]) - min(df["E"])) / (60 * 1000)
# Out:
# 38.405166666666666
